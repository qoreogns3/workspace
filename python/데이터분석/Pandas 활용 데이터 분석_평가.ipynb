# %% [markdown]
# # Pandas 활용 데이터 분석

# %% [markdown]
# 1. 키보드로 세 수를 입력받고,입력받은 세 수를 리스트에 저장하시오. 그 후 리스트에 저장된 수 중 가장 큰 수와 가장 작은 수의 차를 출력하시오.

# %%
#1번 문제 풀이 작성
numList = []
numList.append(int(input('첫번째 수 : ')))
numList.append(int(input('두번째 수 : ')))
numList.append(int(input('세번째 수 : ')))

print(max(numList) - min(numList))
# Out:
# 7

# %% [markdown]
# 2. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 저장된 모든 데이터의 합을 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,2,3] , [4,5,6] / 결과 : 21

# %%
#2번 문제 풀이 작성
def sumList(List1, List2):
  return sum(List1) + sum(List2)

sumList([1,2,3], [4,5,6])
# Out:
# 21

# %% [markdown]
# 3. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 중복으로 저장된 데이터만을 갖는  새로운 리스트를 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,3,5,7,9] , [1,2,3,4,5] / 결과 : [1,3,5]

# %%
#3번 문제 풀이 작성
def equalNum(list1, list2):
  equalList = []
  for e in list1 : 
    for i in list2 :
      if(e == i) : 
        equalList.append(i)
  
  return equalList

equalNum([1,3,5,7,9], [1,2,3,4,5])
# Out:
# [1, 3, 5]

# %% [markdown]
# 4. 이름, 나이, 국어점수, 영어점수, 국어점수를 데이터로 갖는 student 딕셔너리를 만드시오. 각 데이터는 키보드로 입력받아 저장하시오.

# %%
#4번 문제 풀이 작성
student = {
  '국어점수' : int(input('국어 점수 : ')),
  '영어점수' : int(input('영어 점수 : ')),
  '수학점수' : int(input('수학 점수 : '))
}

student
# Out:
# {'국어점수': 100, '영어점수': 80, '수학점수': 90}

# %% [markdown]
# 5. 4번 문제에서 만든 딕셔너리 데이터에 총점 데이터를 추가하시오. 총점 데이터는 국어,영어, 수학점수의 합으로 들어가야합니다.

# %%
#5번 문제 풀이 작성
student['총점'] = student['국어점수'] + student['영어점수'] + student['수학점수']

student
# Out:
# {'국어점수': 100, '영어점수': 80, '수학점수': 90, '총점': 270}

# %% [markdown]
# 6. 아래 딕셔너리 데이터에 stu_grade라는 키를 추가하고, 해당 키의  데이터로  점수(stu_score)에 따른 등급 데이터를 저장하시오.
# 90 <= 점수      : A등급
# 80 <= 점수 < 90 : B등급
# 70 <= 점수 < 80 : C등급
#       점수 < 70 : D등급

# %%
class_room_data = {
    'stu_no' : [1, 2, 3, 4, 5],
    'stu_name' : ['김자바', '이자바', '박자바', '최자바', '정자바'],
    'stu_score' : [85, 65, 70, 80, 95]
}

#6번 문제 풀이 작성
gradeList = []

for e in class_room_data['stu_score'] :
  if e >= 90 :
    gradeList.append('A')
  elif e >= 80 :
    gradeList.append('B')
  elif e >= 70 :
    gradeList.append('C')
  else :
    gradeList.append('D')

class_room_data['stu_grade'] = gradeList

class_room_data
# Out:
# {'stu_no': [1, 2, 3, 4, 5],
#  'stu_name': ['김자바', '이자바', '박자바', '최자바', '정자바'],
#  'stu_score': [85, 65, 70, 80, 95],
#  'stu_grade': ['B', 'D', 'C', 'B', 'A']}

# %% [markdown]
# 7. 아래 데이터는 자바반과 자반에 소속된 학생들의 정보이다.
# 나이가 30살 이상인 학생들의 점수의 합을 출력하세요.

# %%
javaClass= {
  'calssName' : '자바반',
  'teacher' : '김자바',
  'studentList' : [
    {'name' : '홍길동', 'age': 31, 'score' : 85},
    {'name' : '이순신', 'age': 35, 'score' : 95},
    {'name' : '유관순', 'age': 29, 'score' : 80},
    {'name' : '장영실', 'age': 37, 'score' : 70},
    {'name' : '신사임당', 'age': 25, 'score' : 65},
  ]
}

# 7번 문제 답안 작성
sumScore = 0

for e in javaClass['studentList'] : 
  if e['age'] >= 30 :
    sumScore = sumScore + e['score']

sumScore
# Out:
# 250

# %% [markdown]
# 다음 딕셔너리 데이터를 참고하여 아래 문제들을 해결하시오.

# %%
# 2012년 광역시별 25세 미만 연령별 인구 데이터
population = {
    '행정기관' : ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '울산광역시'],
    '0~4세' : [214651, 68006, 53515, 69453, 29835],
    '5~9세' : [210833, 68704, 58332, 68555, 29331],
    '10~14세' : [269171, 94802, 91268, 86574, 29035],
    '15~19세' : [335828, 124564, 101110, 106435, 49119],
    '20~24세' : [343797, 125907, 96078, 102297, 43937]
}

# %% [markdown]
# 8. 2012년 기준 대한민국에서 25세 미만의 인구수 중 인구가 가장 많은 연령대를 출력하시오.

# %%
# 8번 문제 답안 작성

sum(population['0~4세'])
sum(population['5~9세'])
sum(population['10~14세'])
sum(population['15~19세'])
sum(population['20~24세'])
print('15~19세')
# Out:
# 15~19세

# %% [markdown]
# 9. '총 인구수' 라는 키를 추가하고, 해당 키에 0세부터 24세까지의 인구 합을 데이터로 하여 population 데이터에 추가하시오.

# %%
# 9번 문제 답안 작성
totalPeople = []

for e in range(0,5) :
  sumPeople = 0 
  sumPeople = sumPeople + population['0~4세'][e]
  sumPeople = sumPeople + population['5~9세'][e]
  sumPeople = sumPeople + population['10~14세'][e]
  sumPeople = sumPeople + population['15~19세'][e]
  sumPeople = sumPeople + population['20~24세'][e]
  totalPeople.append(sumPeople)

population['총 인구수'] = totalPeople

population
# Out:
# {'행정기관': ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '울산광역시'],
#  '0~4세': [214651, 68006, 53515, 69453, 29835],
#  '5~9세': [210833, 68704, 58332, 68555, 29331],
#  '10~14세': [269171, 94802, 91268, 86574, 29035],
#  '15~19세': [335828, 124564, 101110, 106435, 49119],
#  '20~24세': [343797, 125907, 96078, 102297, 43937],
#  '총 인구수': [1374280, 481983, 400303, 433314, 181257]}
